# %% [markdown]
# # 4. Correlation Matrix
#
# This notebook calculates the curated correlation matrix for resilience and integration variables.
#
# ## Outputs
# - Interactive Plotly heatmap in the notebook
# - Standardized HTML export in `outputs/html/`

# %%
import logging
import sys
from pathlib import Path

from IPython.display import display

project_root = Path.cwd()
if project_root.name == "notebooks":
    project_root = project_root.parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

logging.basicConfig(level=logging.INFO, format="%(levelname)s: %(message)s")

from src.correlation_analysis import (
    calculate_correlation_matrix,
    create_correlation_heatmap,
    export_correlation_heatmap,
    summarize_strong_correlations,
)
from src.data_loader import load_survey_data

survey_df = load_survey_data()
survey_df.head()

# %%
# Plot configuration block
plot_title = "Correlation Matrix: Resilience and Integration Variables"
heatmap_width = 1000
heatmap_height = 850

correlation_df = calculate_correlation_matrix(survey_df)
correlation_figure = create_correlation_heatmap(correlation_df)
export_correlation_heatmap(correlation_figure)

display(correlation_df.round(2))
display(summarize_strong_correlations(correlation_df))
correlation_figure.show()
